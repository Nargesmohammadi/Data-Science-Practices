# %%
import matplotlib.pyplot as plt
img = plt.imread(r'/home/mitraa/imagess/index.jpeg')
img2 = img.copy()

img2[50:100,150:200,0] = 0
img2[50:100,150:200,1] = 1
img2[50:100,150:200,2] = 200

plt.imshow(img2)
